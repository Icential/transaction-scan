# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread("samoyed.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

vector = []
for row in img:
    for val in row:
        vector.append(row)
    
plt.figure(figsize=(30, 5))
plt.plot(vector)
plt.show()
