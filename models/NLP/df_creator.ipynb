# %%
import pandas as pd

# %%
clothing_names = [
    "Baju",
    "Kemeja",
    "Kaos",
    "Celana",
    "Celana Panjang",
    "Celana Pendek",
    "Rok",
    "Dress",
    "Gaun",
    "Jas",
    "Blazer",
    "Jaket",
    "Sweater",
    "Kardigan",
    "Hoodie",
    "Mantel",
    "Rompi",
    "Pakaian Dalam",
    "Bra",
    "Celana Dalam",
    "Kaus Kaki",
    "Stoking",
    "Sepatu",
    "Sandal",
    "Sepatu Bot",
    "Sepatu Olahraga",
    "Topi",
    "Topi Bisbol",
    "Kupluk",
    "Syall",
    "Selendang",
    "Sarung Tangan",
    "Sabuk",
    "Dasi",
    "Dasi Kupu-Kupu",
    "Kacamata",
    "Kacamata Hitam",
    "Kacamata Baca",
    "Piyama",
    "Baju Tidur",
    "Kimono",
    "Baju Renang",
    "Celana Renang",
    "Bikini",
    "Pakaian Dalam Termal",
    "Jas Hujan",
    "Baju Pelindung",
    "Baju Seragam",
    "Baju Kerja",
    "Baju Formal",
    "Blus",
    "Kebaya",
    "Batik",
    "Sarung",
    "Setelan",
    "Jumpsuit",
    "Overall",
    "Legging",
    "Jogger",
    "Chino",
    "Celana Cargo",
    "Celana Jeans",
    "Celana Kulot",
    "Celana Capri",
    "Celana High-Waist",
    "Rok Mini",
    "Rok Maxi",
    "Rok Midi",
    "Rok Lipit",
    "Rok Span",
    "Rok Tutu",
    "Dress Terusan",
    "Dress A-line",
    "Dress Shift",
    "Dress Maxi",
    "Dress Cocktail",
    "Dress Bodycon",
    "Dress Peplum",
    "Blus Peasant",
    "Blus Tunik",
    "Baju Crop",
    "Atasan Off-shoulder",
    "Atasan Halter",
    "Atasan Tank",
    "Kemeja Flanel",
    "Kemeja Polo",
    "Kemeja Formal",
    "Kemeja Kasual",
    "Jaket Denim",
    "Jaket Kulit",
    "Jaket Bomber",
    "Jaket Varsity",
    "Sweater Rajut",
    "Sweater Crewneck",
    "Sweater Turtleneck",
    "Sweater V-neck",
    "Baju Olahraga",
    "Setelan Training",
    "Seragam Sekolah",
    "Baju Pengantin"
]

indonesian_food_names = [
    "Nasi Goreng",
    "Sate Ayam",
    "Gado-Gado",
    "Rendang",
    "Ayam Goreng",
    "Bakso",
    "Soto Ayam",
    "Nasi Uduk",
    "Mie Goreng",
    "Pecel Lele",
    "Ketoprak",
    "Tempeh",
    "Tahu Goreng",
    "Lontong Sayur",
    "Ayam Penyet",
    "Nasi Padang",
    "Sambal Terasi",
    "Babi Guling",
    "Bebek Goreng",
    "Sop Buntut",
    "Sate Kambing",
    "Nasi Liwet",
    "Gudeg",
    "Rawon",
    "Tengkleng",
    "Babi Panggang",
    "Sate Maranggi",
    "Sop Konro",
    "Ikan Bakar",
    "Sate Lilit",
    "Coto Makassar",
    "Bubur Ayam",
    "Pempek",
    "Sayur Asem",
    "Soto Betawi",
    "Asinan Betawi",
    "Tongseng",
    "Balado",
    "Pepes Ikan",
    "Ayam Betutu",
    "Karedok",
    "Martabak Manis",
    "Martabak Telur",
    "Otak-Otak",
    "Lontong Balap",
    "Serabi",
    "Rujak Cingur",
    "Mie Aceh",
    "Tahu Gejrot",
    "Es Campur",
    "Es Teler",
    "Es Cendol",
    "Kue Cubit",
    "Kue Lumpur",
    "Kue Putu",
    "Klepon",
    "Risoles",
    "Pastel",
    "Lemper",
    "Onde-Onde",
    "Bolu Kukus",
    "Pisang Goreng",
    "Lapis Legit",
    "Nasi Kuning",
    "Sambal Matah",
    "Sambal Bajak",
    "Dadar Gulung",
    "Getuk",
    "Bika Ambon",
    "Kerak Telor",
    "Bumbu Pecel",
    "Arem-Arem",
    "Bakmi Jawa",
    "Kue Pancong",
    "Kue Ape",
    "Tiwul",
    "Roti Bakar",
    "Bubur Sumsum",
    "Bubur Kacang Hijau",
    "Kolak",
    "Sate Padang",
    "Sate Taichan",
    "Mie Kocok",
    "Empal Gentong",
    "Nasi Timbel",
    "Tahu Sumedang",
    "Batagor",
    "Siomay",
    "Mie Bangka",
    "Lempok Durian",
    "Srikaya Palembang",
    "Ayam Pop",
    "Singkong Keju",
    "Tiwul Ayu",
    "Pindang Patin",
    "Pindang Serani",
    "Tekwan",
    "Sate Madura",
    "Ayam Rica-Rica",
    "Ikan Asin",
    "Roti",
    "Nasi",
    "Ayam",
    "Ikan",
    "Daging Sapi",
    "Daging Babi",
    "Telur",
    "Keju",
    "Susu",
    "Mentega",
    "Pasta",
    "Pizza",
    "Hamburger",
    "Sandwich",
    "Salad",
    "Sup",
    "Kentang Goreng",
    "Roti Bakar",
    "Pancake",
    "Wafel",
    "Cokelat",
    "Es Krim",
    "Kue",
    "Biskuit",
    "Puding",
    "Yogurt",
    "Buah Apel",
    "Pisang",
    "Jeruk",
    "Anggur",
    "Melon",
    "Semangka",
    "Mangga",
    "Nanas",
    "Stroberi",
    "Tomat",
    "Wortel",
    "Brokoli",
    "Bayam",
    "Selada",
    "Jagung",
    "Kacang Hijau",
    "Kacang Merah",
    "Kacang Kedelai",
    "Jamur",
    "Bawang Putih",
    "Bawang Merah",
    "Jahe",
    "Lada Hitam",
    "Garam",
    "Gula",
    "Madu",
    "Selai Kacang",
    "Saus Tomat",
    "Mayones",
    "Mustard",
    "Cuka",
    "Minyak Zaitun",
    "Minyak Kelapa",
    "Minyak Wijen",
    "Teh",
    "Kopi",
    "Jus Jeruk",
    "Air Kelapa",
    "Bir",
    "Anggur Merah",
    "Anggur Putih",
    "Sate",
    "Sushi",
    "Sashimi",
    "Tacos",
    "Burritos",
    "Nachos",
    "Falafel",
    "Hummus",
    "Paella",
    "Tapas",
    "Ratatouille",
    "Lasagna",
    "Spaghetti",
    "Tiramisu",
    "Croissant",
    "Bagel",
    "Donat",
    "Muffin",
    "Sereal",
    "Popcorn",
    "Nasi Goreng",
    "Mie Goreng",
    "Tempura",
    "Kimchi",
    "Bibimbap",
    "Pho",
    "Gyoza",
    "Dim Sum",
    "Spring Roll",
    "Lumpia",
    "Kari",
    "Naan",
    "Roti Canai"
]

items = indonesian_food_names + clothing_names

# %%
cats = []
for i in range(200):
    cats.append("Food")

for i in range(100):
    cats.append("Clothing")

# %%
df = pd.DataFrame({
    "Text": items,
    "Category": cats
})

# %%
df.to_csv("train.csv", index=False)

# %%
df = pd.DataFrame({
    "Text": ["beli baju", "jual kaos", "beli pizza", "beli makanan", "jual soto", "jual celana", "beli sepatu", "jual ayam", "beli roti", "beli kaos"],
    "Category": ["Clothing", "Clothing", "Food", "Food", "Food", "Clothing", "Clothing", "Food", "Food", "Clothing"]
})

# %%
df.to_csv("test.csv", index=False)

# %% [markdown]
# ===============ADDITIONAL================

# %%
import pandas as pd

sentences = [
    "Saya suka makan nasi goreng.",
    "Dia memakai kemeja putih hari ini.",
    "Ayah saya sangat suka rendang.",
    "Saya butuh jaket baru untuk musim dingin.",
    "Kami sering makan bakso di sore hari.",
    "Mereka membeli baju baru di pasar.",
    "Saya memesan sate ayam untuk makan malam.",
    "Ibu saya suka memakai rok panjang.",
    "Kami selalu minum jus jeruk di pagi hari.",
    "Adik saya senang makan es krim.",
    "Dia sedang mencari celana jeans yang nyaman.",
    "Saya sarapan dengan roti bakar dan teh.",
    "Dia membawa salad untuk makan siang.",
    "Mereka makan ikan bakar di restoran.",
    "Kami memesan pizza untuk acara ulang tahun.",
    "Dia selalu memakai sweater saat cuaca dingin.",
    "Saya suka makan mie goreng setiap malam.",
    "Dia suka memakai topi saat bepergian.",
    "Kami sering makan pempek di rumah.",
    "Dia membeli gaun baru untuk pesta.",
    "Saya suka makan martabak manis.",
    "Dia mengenakan sepatu olahraga ke gym.",
    "Kami makan nasi uduk di pagi hari.",
    "Dia suka memakai blus merah.",
    "Saya sering makan soto ayam saat hujan.",
    "Dia membeli celana pendek untuk liburan.",
    "Kami suka makan gudeg di Yogyakarta.",
    "Dia mengenakan kacamata hitam di pantai.",
    "Saya makan ketoprak untuk sarapan.",
    "Dia memakai jaket kulit di malam hari.",
    "Kami minum kopi setiap pagi.",
    "Dia suka makan rendang di restoran Padang.",
    "Saya membeli sandal baru di toko.",
    "Kami sering makan serabi di sore hari.",
    "Dia selalu memakai kardigan saat bekerja.",
    "Saya suka makan sate lilit di Bali.",
    "Dia membeli tas baru di pasar malam.",
    "Kami makan gado-gado untuk makan siang.",
    "Dia memakai jas saat pertemuan bisnis.",
    "Saya makan rujak cingur di Malang.",
    "Dia memakai topi bisbol saat berolahraga.",
    "Kami minum teh hijau setiap sore.",
    "Dia suka makan tekwan di Palembang.",
    "Saya memakai piyama saat tidur.",
    "Kami sering makan soto betawi di Jakarta.",
    "Dia membeli dasi kupu-kupu untuk pesta.",
    "Saya suka makan lontong sayur di pagi hari.",
    "Dia memakai sepatu bot saat hujan.",
    "Kami makan pecel lele di warung makan.",
    "Dia membeli kupluk untuk musim dingin.",
    "Saya makan bubur ayam untuk sarapan.",
    "Dia suka memakai blus putih.",
    "Kami sering makan otak-otak di rumah.",
    "Dia memakai sarung tangan saat berkebun.",
    "Saya suka makan kue cubit di sore hari.",
    "Dia membeli celana cargo untuk hiking.",
    "Kami makan ayam betutu di Bali.",
    "Dia mengenakan baju formal untuk rapat.",
    "Saya makan bubur kacang hijau setiap pagi.",
    "Dia memakai mantel saat salju turun.",
    "Kami suka makan tahu goreng di rumah.",
    "Dia memakai sepatu bot saat musim hujan.",
    "Saya makan nasi kuning di acara ulang tahun.",
    "Dia membeli dasi baru untuk bekerja.",
    "Kami sering makan singkong keju di sore hari.",
    "Dia mengenakan kemeja flanel saat jalan-jalan.",
    "Saya suka makan getuk di sore hari.",
    "Dia membeli celana chino untuk bekerja.",
    "Kami makan nasi padang di restoran.",
    "Dia memakai rompi saat bersepeda.",
    "Saya makan tahu sumedang saat di Bandung.",
    "Dia membeli jaket denim untuk musim gugur.",
    "Kami sering makan batagor di Bandung.",
    "Dia suka memakai baju tidur saat liburan.",
    "Saya makan pisang goreng di sore hari.",
    "Dia membeli sepatu baru di toko.",
    "Kami makan siomay di pasar malam.",
    "Dia memakai kardigan saat bekerja.",
    "Saya suka makan bubur sumsum di pagi hari.",
    "Dia membeli rok maxi untuk pesta.",
    "Kami sering makan empal gentong di Cirebon.",
    "Dia suka memakai topi saat berjalan-jalan.",
    "Saya makan mie aceh di restoran.",
    "Dia membeli gaun baru untuk acara.",
    "Kami makan nasi timbel di warung.",
    "Dia suka memakai blus biru.",
    "Saya makan lontong balap di Surabaya.",
    "Dia membeli celana kulot untuk bekerja.",
    "Kami sering makan karedok di rumah.",
    "Dia suka memakai sepatu olah raga saat jogging.",
    "Saya makan martabak telur di malam hari.",
    "Dia membeli tas baru di pusat perbelanjaan.",
    "Kami makan coto makassar di restoran.",
    "Dia mengenakan baju pengantin saat pernikahan.",
    "Saya suka makan bika ambon di sore hari.",
    "Dia membeli celana high-waist untuk bekerja."
]

categories = ["food" if any(food.lower() in sentence for food in indonesian_food_names) else "clothing" for sentence in sentences]

df = pd.DataFrame({"Sentence": sentences, "Category": categories})

df.to_csv("re.csv", index=False)
