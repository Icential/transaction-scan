# %% [markdown]
# ### General Concept

# %% [markdown]
# 1. Given a pdf file of a bank transaction with multiple pages, get png/jpg of each page.
# 2. With png/jpg, detect relevant texts (e.g. Tanggal, Keterangan, Mutasi)
# 3. Put detected text into a DataFrame to be converted into a CSV file that is seperated by semicolons ;

# %% [markdown]
# Current issue: 1st page is empty
#
# Current solution: Explicitly define page number

# %% [markdown]
# ### Import Dump

# %%
import cv2
import pandas as pd
import fitz
import matplotlib.pyplot as plt
import pytesseract
import warnings


warnings.simplefilter(action='ignore', category=FutureWarning)
# Out:
# c:\Users\paoma\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %% [markdown]
# ### Scanning

# %% [markdown]
# First we convert the pdf into a png per page

# %%
pdf_name = "DANAMON_PERSONAL.pdf"

doc = fitz.open(pdf_name)

for page in doc:
    pix = page.get_pixmap(dpi=600)
    name = pdf_name[:-4] + "-page-" + str(page.number) + ".png"
    pix.save(name)

# %% [markdown]
# Use an OCR (optical character recognition) model for reading text

# %%
# define tesseract OCT model 
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %% [markdown]
# Read the images to be put into an Image object in cv2

# %%
page_num = 0

page_name = pdf_name[:-4] + "-page-" + str(page_num) + ".png"

# read png
page = cv2.imread(page_name)

# to grayscale for model to easily process
page = cv2.cvtColor(page, cv2.COLOR_BGR2GRAY)

# show page image
plt.figure(figsize=(30,8))
plt.imshow(page, cmap="gray")

# %% [markdown]
# The important part of this file is below the row with "Tanggal, Keterangan, ...". So crop this part. Assume that the height ratio proportion of this bank statement to be stable.
#
# The height crop in this image should be around the 2050th pixel and the image is 7017 pixels high. So the ratio is 2050/7017 which is around 0.298. So crop at the 29.8% height of the image regardless of the image size.

# %%
# get page height
page_height = page.shape[0]

# start of table is different per page
if page_num == 0:
    page = page[int(page_height * 0.365):, :]
else:
    page = page[int(page_height * 0.332):, :]

plt.figure(figsize=(30,8))
plt.imshow(page, cmap="gray")

# %% [markdown]
# Create a threshold for creating pure monochrome image

# %%
# define threshold
retval, thresh = cv2.threshold(page, 0, 255, cv2.THRESH_OTSU | cv2.THRESH_BINARY_INV)

# show monochrome image
plt.figure(figsize=(30,8))
plt.imshow(thresh, cmap="gray")

# %% [markdown]
# Extract text using contours (rectangles around text) more simply for the model to detect characters.

# %%
# dilation parameter; bigger tuple = smaller rectangle
rect_kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (13, 13))

# apply dilation to the thresholded monochrome image
dilation = cv2.dilate(thresh, rect_kernel, iterations=1)

# find contours and rectangles
contours, hierarchy = cv2.findContours(dilation, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

# copy grayscale image from earlier to see the contours
page_copy = page.copy()

# make contour list to store text and its corresponding coordinates
cnt_list = []

# loop for each contour detected
for cnt in contours:

    # get coordinates of contours
    x, y, w, h = cv2.boundingRect(cnt)

    # draw rectangle for each contour
    cv2.rectangle(page_copy, (x, y), (x + w, y + h), (0, 255, 0), 2)

    # crop text block by rectangle text block
    crop = page_copy[y:y+h, x:x+w]

    # use ocr model cropped image
    text = pytesseract.image_to_string(crop, config="--psm 13")

    # store coordinates and text
    cnt_list.append([x, y, text])

plt.figure(figsize=(30,8))
plt.imshow(page_copy, cmap="gray")

# %% [markdown]
# Sort text from left to right and from up to down

# %%
sorted_list = sorted(cnt_list, key = lambda x: x[0]) # sort by width first
sorted_list = sorted(sorted_list, key = lambda x: x[1]) # then height

sorted_list
# Out:
# [[785, 23, 'SALDO\n'],
#  [1001, 23, 'BULAN\n'],
#  [1212, 23, 'LALU\n'],
#  [4346, 24, '301\n'],
#  [4446, 24, '5358.49\n'],
#  [404, 115, '/03\n'],
#  [576, 115, '01/03\n'],
#  [787, 115, 'PRIMA\n'],
#  [984, 115, 'TRE\n'],
#  [1456, 115, 'CA\n'],
#  [341, 116, '01\n'],
#  [1114, 116, '20500654\n'],
#  [1378, 116, '1\n'],
#  [1406, 116, '6\n'],
#  [2128, 116, '601\n'],
#  [2226, 116, '701\n'],
#  [2323, 116, '0061\n'],
#  [2457, 116, '1\n'],
#  [2485, 116, '9\n'],
#  [2936, 116, '1\n'],
#  [2965, 116, '30,000.00\n'],
#  [4350, 116, '1\n'],
#  [4379, 116, '71\n'],
#  [4446, 116, '5358.49\n'],
#  [1273, 173, 'BANK\n'],
#  [784, 174, '61\n'],
#  [853, 174, '1\n'],
#  [881, 174, '970\n'],
#  [995, 174, '601\n'],
#  [1093, 174, '701\n'],
#  [1189, 174, '(ore)\n'],
#  [787, 232, 'DANAMON\n'],
#  [1102, 232, 'INDONES\n'],
#  [1384, 232, 'IA\\\\\n'],
#  [783, 290, 'JK\\\n'],
#  [404, 382, '/03\n'],
#  [576, 382, '01/03\n'],
#  [787, 382, 'BERS\n'],
#  [958, 382, 'TRE\n'],
#  [341, 383, '01\n'],
#  [1089, 383, '8930898481\n'],
#  [2128, 383, '601\n'],
#  [2226, 383, '701\n'],
#  [2323, 383, '008795\n'],
#  [2965, 383, '20,000.00\n'],
#  [4350, 383, '1\n'],
#  [4378, 383, '51\n'],
#  [4446, 383, '5358.49\n'],
#  [1413, 384, '5555\n'],
#  [783, 440, 'ANDIRI\n'],
#  [998, 441, '879568\n'],
#  [1209, 441, '601\n'],
#  [1307, 441, '701\n'],
#  [1403, 441, '(ore)\n'],
#  [787, 498, 'BANK\n'],
#  [962, 498, 'DANAMON\n'],
#  [1277, 498, 'INDONESIA\\\\\n'],
#  [783, 557, 'JK\\\n'],
#  [404, 648, '/03\n'],
#  [576, 648, '01/03\n'],
#  [787, 648, 'BERS\n'],
#  [958, 648, 'TRE\n'],
#  [1092, 648, 'FEE\n'],
#  [341, 649, '01\n'],
#  [3033, 649, '1500.00\n'],
#  [4350, 649, '1\n'],
#  [4378, 649, '43,858.49\n'],
#  [2998, 650, '7\n'],
#  [1257, 707, 'B\n'],
#  [1308, 707, 'ANK\n'],
#  [784, 708, '879568601\n'],
#  [1077, 708, '701\n'],
#  [1173, 708, '(re)\n'],
#  [787, 765, 'DANAMON\n'],
#  [1102, 765, 'INDONESIA\\\\\n'],
#  [1467, 765, 'JK\\\n'],
#  [341, 857, '02/03\n'],
#  [576, 857, '02/03\n'],
#  [787, 857, 'BERS\n'],
#  [958, 857, 'TRE\n'],
#  [1089, 858, '8930898481\n'],
#  [2128, 858, '601\n'],
#  [2226, 858, '701\n'],
#  [2323, 858, '003036\n'],
#  [2969, 858, '1\n'],
#  [2997, 858, '0,000.00\n'],
#  [4350, 858, '1\n'],
#  [4378, 858, '33,858.49\n'],
#  [1413, 859, '5555\n'],
#  [783, 915, 'ANDIRI\n'],
#  [998, 916, '303694\n'],
#  [1209, 916, '601\n'],
#  [1307, 916, '701\n'],
#  [1403, 916, '(ore)\n'],
#  [787, 973, 'BANK\n'],
#  [962, 973, 'DANAMON\n'],
#  [1277, 973, 'INDONESIA\\\\\n'],
#  [783, 1032, 'JK\\\n'],
#  [341, 1123, '02/03\n'],
#  [576, 1123, '02/03\n'],
#  [787, 1123, 'BERS\n'],
#  [958, 1123, 'TRE\n'],
#  [1092, 1123, 'FEE\n'],
#  [3033, 1124, '1500.00\n'],
#  [4350, 1124, '1\n'],
#  [4378, 1124, '26,358.49\n'],
#  [2998, 1125, '7\n'],
#  [1257, 1182, 'B\n'],
#  [1308, 1182, 'ANK\n'],
#  [784, 1183, '303694601\n'],
#  [1077, 1183, '701\n'],
#  [1173, 1183, '(re)\n'],
#  [787, 1240, 'DANAMON\n'],
#  [1102, 1240, 'INDONESIA\\\\\n'],
#  [1467, 1240, 'JK\\\n'],
#  [341, 1332, '02/03\n'],
#  [576, 1332, '02/03\n'],
#  [787, 1332, 'BERS\n'],
#  [958, 1332, 'TRE\n'],
#  [1089, 1333, '8930898481\n'],
#  [2128, 1333, '601\n'],
#  [2226, 1333, '701\n'],
#  [2323, 1333, '005366\n'],
#  [2965, 1333, '20,000.00\n'],
#  [4350, 1333, '1\n'],
#  [4378, 1333, '06,358.49\n'],
#  [1413, 1334, '5555\n'],
#  [783, 1390, 'ANDIRI\n'],
#  [998, 1391, '536649\n'],
#  [1209, 1391, '601\n'],
#  [1307, 1391, '701\n'],
#  [1403, 1391, '(ore)\n'],
#  [787, 1448, 'BANK\n'],
#  [962, 1448, 'DANAMON\n'],
#  [1277, 1448, 'INDONESIA\\\\\n'],
#  [783, 1507, 'JK\\\n'],
#  [341, 1598, '02/03\n'],
#  [576, 1598, '02/03\n'],
#  [787, 1598, 'BERS\n'],
#  [958, 1598, 'TRE\n'],
#  [1092, 1598, 'FEE\n'],
#  [3033, 1599, '1500.00\n'],
#  [4378, 1599, '98,858.49\n'],
#  [2998, 1600, '7\n'],
#  [1257, 1657, 'B\n'],
#  [1308, 1657, 'ANK\n'],
#  [784, 1658, '536649601\n'],
#  [1077, 1658, '701\n'],
#  [1173, 1658, '(re)\n'],
#  [787, 1715, 'DANAMON\n'],
#  [1102, 1715, 'INDONESIA\\\\\n'],
#  [1467, 1715, 'JK\\\n'],
#  [341, 1807, '03/03\n'],
#  [576, 1807, '03/03\n'],
#  [787, 1807, 'BERS\n'],
#  [958, 1807, 'TRE\n'],
#  [1089, 1808, '8930898481\n'],
#  [2128, 1808, '601\n'],
#  [2226, 1808, '701\n'],
#  [2323, 1808, '0071\n'],
#  [2453, 1808, '04\n'],
#  [2965, 1808, '20,000.00\n'],
#  [4379, 1808, '78,858.49\n'],
#  [1413, 1809, '5555\n'],
#  [783, 1865, 'ANDIRI\n'],
#  [999, 1866, '7 1\n'],
#  [1063, 1866, '0434\n'],
#  [1209, 1866, '601\n'],
#  [1307, 1866, '701\n'],
#  [1403, 1866, '(ore)\n'],
#  [787, 1923, 'BANK\n'],
#  [962, 1923, 'DANAMON\n'],
#  [1277, 1923, 'INDONESIA\\\\\n'],
#  [783, 1982, 'JK\\\n'],
#  [341, 2073, '03/03\n'],
#  [576, 2073, '03/03\n'],
#  [787, 2073, 'BERS\n'],
#  [958, 2073, 'TRE\n'],
#  [1092, 2073, 'FEE\n'],
#  [3033, 2074, '1500.00\n'],
#  [4379, 2074, '71\n'],
#  [4446, 2074, '5358.49\n'],
#  [2998, 2075, '7\n'],
#  [1257, 2132, 'B\n'],
#  [1308, 2132, 'ANK\n'],
#  [785, 2133, '7 1\n'],
#  [849, 2133, '0434601\n'],
#  [1077, 2133, '701\n'],
#  [1173, 2133, '(re)\n'],
#  [787, 2190, 'DANAMON\n'],
#  [1102, 2190, 'INDONESIA\\\\\n'],
#  [1467, 2190, 'JK\\\n'],
#  [341, 2282, '05/03\n'],
#  [576, 2282, '05/03\n'],
#  [787, 2282, 'BERS\n'],
#  [958, 2282, 'TRE\n'],
#  [1089, 2283, '8930898481\n'],
#  [2128, 2283, '601\n'],
#  [2226, 2283, '701\n'],
#  [2323, 2283, '001\n'],
#  [2420, 2283, '563\n'],
#  [2965, 2283, '38,000.00\n'],
#  [4378, 2283, '33,358.49\n'],
#  [1413, 2284, '5555\n'],
#  [783, 2340, 'ANDIRI\n'],
#  [1002, 2341, '1\n'],
#  [1030, 2341, '56397\n'],
#  [1209, 2341, '601\n'],
#  [1307, 2341, '701\n'],
#  [1403, 2341, '(ore)\n'],
#  [787, 2398, 'BANK\n'],
#  [962, 2398, 'DANAMON\n'],
#  [1277, 2398, 'INDONESIA\\\\\n'],
#  [783, 2457, 'JK\\\n'],
#  [341, 2548, '05/03\n'],
#  [576, 2548, '05/03\n'],
#  [787, 2548, 'BERS\n'],
#  [958, 2548, 'TRE\n'],
#  [1092, 2548, 'FEE\n'],
#  [3033, 2549, '1500.00\n'],
#  [4378, 2549, '25,858.49\n'],
#  [2998, 2550, '7\n'],
#  [1257, 2607, 'B\n'],
#  [1308, 2607, 'ANK\n'],
#  [788, 2608, '1\n'],
#  [816, 2608, '56397601\n'],
#  [1077, 2608, '701\n'],
#  [1173, 2608, '(re)\n'],
#  [787, 2665, 'DANAMON\n'],
#  [1102, 2665, 'INDONESIA\\\\\n'],
#  [1467, 2665, 'JK\\\n'],
#  [341, 2757, '08/03\n'],
#  [576, 2757, '08/03\n'],
#  [783, 2757, 'THP\n'],
#  [2388, 2758, '3955\n'],
#  [3590, 2758, '4,395,452.00\n'],
#  [4297, 2758, '4,421\n'],
#  [4446, 2758, 'Lol\n'],
#  [4524, 2758, '0.49\n'],
#  [341, 2848, '08/03\n'],
#  [576, 2848, '08/03\n'],
#  [787, 2848, 'PRIMA\n'],
#  [984, 2848, 'TRE\n'],
#  [1456, 2848, 'CA\n'],
#  [1114, 2849, '0948525871\n'],
#  [2128, 2849, '601\n'],
#  [2226, 2849, '701\n'],
#  [2323, 2849, '001\n'],
#  [2420, 2849, '657\n'],
#  [2884, 2849, '4,200,000.00\n'],
#  [4346, 2849, '221\n'],
#  [4446, 2849, 'Lol\n'],
#  [4524, 2849, '0.49\n'],
#  [1273, 2907, 'BANK\n'],
#  [788, 2908, '1\n'],
#  [816, 2908, '65778\n'],
#  [995, 2908, '601\n'],
#  [1093, 2908, '701\n'],
#  [1189, 2908, '(ore)\n'],
#  [787, 2965, 'DANAMON\n'],
#  [1102, 2965, 'INDONES\n'],
#  [1384, 2965, 'IA\\\\\n'],
#  [783, 3023, 'JK\\\n'],
#  [341, 3115, '09/03\n'],
#  [576, 3115, '09/03\n'],
#  [787, 3115, 'BERS\n'],
#  [958, 3115, 'TRE\n'],
#  [1089, 3116, '8930898481\n'],
#  [2128, 3116, '601\n'],
#  [2226, 3116, '701\n'],
#  [2323, 3116, '003330\n'],
#  [2965, 3116, '20,000.00\n'],
#  [4346, 3116, '201\n'],
#  [4446, 3116, 'Lol\n'],
#  [4524, 3116, '0.49\n'],
#  [1413, 3117, '5555\n'],
#  [783, 3173, 'ANDIRI\n'],
#  [998, 3174, '333023\n'],
#  [1209, 3174, '601\n'],
#  [1307, 3174, '701\n'],
#  [1403, 3174, '(ore)\n'],
#  [787, 3232, 'BANK\n'],
#  [962, 3232, 'DANAMON\n'],
#  [1277, 3232, 'INDONESIA\\\\\n'],
#  [783, 3290, 'JK\\\n'],
#  [302, 3448, 'a\n'],
#  [334, 4217, '14446765/LB/BD_SingleStatementMail_Hold.txt-2021\n'],
#  [1523, 4218, '0402-1\n']]

# %% [markdown]
# Make into DataFrame for 2D array manipulation to make it cleaner

# %%
# create dataframe
df = pd.DataFrame(sorted_list)
df.columns = ["x", "y", "Text"]

# omit trivial texts
df = df.drop(df[(df.Text == "")].index)

# Remove the \n in text
df["Text"] = df["Text"].str.replace("\n", "")
df = df.drop(df[(df.Text == "|") | (df.Text == "| |")].index)

df.head(20)
# Out:
#        x    y      Text
# 0    785   23     SALDO
# 1   1001   23     BULAN
# 2   1212   23      LALU
# 3   4346   24       301
# 4   4446   24   5358.49
# 5    404  115       /03
# 6    576  115     01/03
# 7    787  115     PRIMA
# 8    984  115       TRE
# 9   1456  115        CA
# 10   341  116        01
# 11  1114  116  20500654
# 12  1378  116         1
# 13  1406  116         6
# 14  2128  116       601
# 15  2226  116       701
# 16  2323  116      0061
# 17  2457  116         1
# 18  2485  116         9
# 19  2936  116         1

# %% [markdown]
# Each perceieved row in the image is seen to have a range of 2-5 pixels in its y (e.g. 43, 44, 45) by the model but it is important to make it so that it is in the same y that the paper is actually trying to tell
#
# So replace a row's y point (defined as the top left of the row or contour) and everything that is near that y point (y+5) to be y
#
# (To be optimized with df functions; or not? the runtime is 0s)

# %%
r = 0

for i in range(df.shape[0]):
    if i == 0:
        r = df["y"].iloc[0]

    y = df["y"].iloc[i]

    if y <= r+5:
        df["y"].iloc[i] = r
    else:
        r = y

# sort again left to right, top to bottom
df = df.sort_values(by=["y", "x"])

# delete saldo awal
if df["Text"].iloc[0].strip() == "SALDO":
    saldo_y = df["y"].iloc[0]
    df = df.drop(df[df.y == saldo_y].index)


df.head(20)
# Out:
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
# C:\Users\paoma\AppData\Local\Temp\ipykernel_22668\1937316669.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["y"].iloc[i] = r
#        x    y       Text
# 0    341  115         01
# 1    404  115        /03
# 2    576  115      01/03
# 3    787  115      PRIMA
# 4    984  115        TRE
# 5   1114  115   20500654
# 6   1378  115          1
# 7   1406  115          6
# 8   1456  115         CA
# 9   2128  115        601
# 10  2226  115        701
# 11  2323  115       0061
# 12  2457  115          1
# 13  2485  115          9
# 14  2936  115          1
# 15  2965  115  30,000.00
# 16  4350  115          1
# 17  4379  115         71
# 18  4446  115    5358.49
# 19   784  173         61

# %% [markdown]
# A row in the transaction is defined by each date's position. Similarly in the desired CSV, the same row shall have all of its elements with it.
#
# The date's x is always the most left (+/-5) so get the smallest x and split the dataset based on when each date is detected per row.
#
# It is also desirable to make every element have its x known to detect which column it is in

# %% [markdown]
# Create a new DataFrame where columns store each column in the page (Tanggal, Keterangan, CBG, Mutasi, Saldo) and put each transaction row into one row. Keterangan will have multiple string elements concatenated

# %%
t = pd.DataFrame(columns=["Tgl Trans", "Tgl Valuta", "Keterangan", "Reff", "Debit", "Kredit", "Saldo"])

# %% [markdown]
# Find each left x coordinate of each column. First do a manual search of each x coordinate by plotting vertical lines in the page

# %%
page_lines = page_copy.copy()
page_lines = cv2.cvtColor(page_lines, cv2.COLOR_GRAY2BGR)

line_xs = [550, 750, 1800, 2600, 3350, 4000]

for x in line_xs:
    cv2.line(page_lines, (x, 0), (x, page.shape[0]), (255, 0, 0), 4, cv2.LINE_AA)

plt.figure(figsize=(30, 8))
plt.imshow(page_lines)

# %% [markdown]
# Therefore for each column, its x coordinates are:
# - Tgl Trans: x < 550
# - Tgl Valuta: 550 < x < 750
# - Keterangan: 750 < x < 1800
# - Reff: 1800 < x < 2600
# - Debit: 2600 < x < 3350
# - Kredit: 3350 < x < 4000
# - Saldo: 4000 < x

# %%
tt="";tv="";keterangan="";reff="";debit="";kredit="";saldo=""
tts=[];tvs=[];keterangans=[];reffs=[];debits=[];kredits=[];saldos=[]

# prevents summary at the end of pdf to be added
# exit = 0 # if SALDO and AWAL is detected in columns keterangan1 and keterangan2 correspondingly, append arrays and break

df = df._append({"x": 500, "y": 0, "Text": "a"}, ignore_index=True)

for i in range(df.shape[0]):
    x = df["x"].iloc[i]
    text = df["Text"].iloc[i]
    
    if x < 550:
        if tv != "":
            tts.append(tt)
            tvs.append(tv)
            keterangans.append(keterangan)
            reffs.append(reff)
            debits.append(debit)
            kredits.append(kredit)
            saldos.append(saldo)

            tt="";tv="";keterangan="";reff="";debit="";kredit="";saldo=""
        
        tt += text
    elif 550 < x < 750:
        tv += text + " "
    elif 750 < x < 1800:
        if text.strip() == "TOTAL":
            tts.append(tt)
            tvs.append(tv)
            keterangans.append(keterangan)
            reffs.append(reff)
            debits.append(debit)
            kredits.append(kredit)
            saldos.append(saldo)

            break
        else:
            keterangan += text + " "
    elif 1800 < x < 2600:
        reff += text
    elif 2600 < x < 3350:
        debit += text
    elif 3350 < x < 4000:
        kredit += text
    elif 4000 < x:
        saldo += text

t = pd.DataFrame({
            "Tgl Trans": tts,
            "Tgl Valuta": tvs,
            "Keterangan": keterangans,
            "Reff": reffs,
            "Debit": debits,
            "Kredit": kredits,
            "Saldo": saldos
        })

t = t[t["Tgl Trans"].str.contains("a") == False] # delete
t = t[(t["Tgl Trans"] == "") == False]


t
# Out:
#    Tgl Trans Tgl Valuta                                         Keterangan  \
# 0      01/03     01/03   PRIMA TRE 20500654 1 6 CA 61 1 970 601 701 (or...
# 1      01/03     01/03   BERS TRE 8930898481 5555 ANDIRI 879568 601 701...
# 2      01/03     01/03   BERS TRE FEE 879568601 701 (re) B ANK DANAMON ...
# 3      02/03     02/03   BERS TRE 8930898481 5555 ANDIRI 303694 601 701...
# 4      02/03     02/03   BERS TRE FEE 303694601 701 (re) B ANK DANAMON ...
# 5      02/03     02/03   BERS TRE 8930898481 5555 ANDIRI 536649 601 701...
# 6      02/03     02/03   BERS TRE FEE 536649601 701 (re) B ANK DANAMON ...
# 7      03/03     03/03   BERS TRE 8930898481 5555 ANDIRI 7 1 0434 601 7...
# 8      03/03     03/03   BERS TRE FEE 7 1 0434601 701 (re) B ANK DANAMO...
# 9      05/03     05/03   BERS TRE 8930898481 5555 ANDIRI 1 56397 601 70...
# 10     05/03     05/03   BERS TRE FEE 1 56397601 701 (re) B ANK DANAMON...
# 11     08/03     08/03                                                THP
# 12     08/03     08/03   PRIMA TRE 0948525871 CA 1 65778 601 701 (ore) ...
# 13     09/03     09/03   BERS TRE 8930898481 5555 ANDIRI 333023 601 701...
#
#             Reff         Debit        Kredit         Saldo
# 0   601701006119    130,000.00                  1715358.49
# 1   601701008795     20,000.00                  1515358.49
# 2                     71500.00                  143,858.49
# 3   601701003036     10,000.00                  133,858.49
# 4                     71500.00                  126,358.49
# 5   601701005366     20,000.00                  106,358.49
# 6                     71500.00                   98,858.49
# 7   601701007104     20,000.00                   78,858.49
# 8                     71500.00                   715358.49
# 9   601701001563     38,000.00                   33,358.49
# 10                    71500.00                   25,858.49
# 11          3955                4,395,452.00  4,421Lol0.49
# 12  601701001657  4,200,000.00                  221Lol0.49
# 13  601701003330     20,000.00                  201Lol0.49

# %% [markdown]
# String postprocessing so the csv looks neater

# %%
# remove every element's last character (which is some unnecessary space)
t["Keterangan"] = t["Keterangan"].str[:-1]

# %%
# no space in dates amnd values
for column in t.columns:
    if column != "Keterangan":
        t[column] = t[column].str.replace(" ", "")

# emphasize perak in amount
for i in range(t.shape[0]):
    d = t["Debit"].iloc[i]
    k = t["Kredit"].iloc[i]
    s = t["Saldo"].iloc[i]

    if d[-3:-2] != ".":
        t["Debit"].iloc[i] = d[:-2] + "." + d[-2:]

    if k[-3:-2] != ".":
        t["Kredit"].iloc[i] = k[:-2] + "." + k[-2:]

    if s[-3:-2] != ".":
        t["Saldo"].iloc[i] = s[:-2] + "." + s[-2:]

t
# Out:
#    Tgl Trans Tgl Valuta                                         Keterangan  \
# 0      09/03      09/03  BERS TRE FEE 333023601 701 (re) B ANK DANAMON ...
# 1      09/03      09/03  PRIMA 730 S11 G9972ZX BANK CENTRA L ASIA\\DEPO...
# 2      09/03      09/03  PRIMA W/D FEE '730S1 G9972ZX BAN K CENTRAL ASI...
# 3     110/03      10/03                       GAJIANDULUAN.ID_FLP551 99 29
# 4      11/03      11/03  PRIMA 1 28 S11 G997Z8 BANK CENTR AL ASIA\\DEPO...
# 5      11/03      11/03  BERS TRE 8930898481 5555 ANDIRI 1 50874 601 70...
# 6      11/03      11/03  BERS TRE FEE 1 50874601 701 (re) B ANK DANAMON...
# 7      15/03      15/03                        MONTHL YY ADMINISTRATION FE
# 8      15/03      15/03                              PENAL TY BELOW MIN BA
# 9      31/03      31/03                         CREDIT INTEREST CAPITALISE
# 10     31/03      31/03                                        TAX DEDUCTE
#
#               Reff       Debit      Kredit       Saldo
# 0                     71500.00           .  193,810.49
# 1     S11G9972X730  150,000.00           .   43,810.49
# 2                     71500.00           .   36,310.49
# 3    0273633548809           .  950,000.00  986,310.49
# 4   S11G9972Z82128  900,000.00           .   86,310.49
# 5     601701001508   50,000.00           .   36,310.49
# 6                     71500.00           .   28,810.49
# 7                     5,000.00           .   23,810.49
# 8                     5,000.00           .   18,810.49
# 9                            .       20.27  18,830!.76
# 10                        4.05           .  18,826!.71

# %% [markdown]
# Finally put the dataframe into csv

# %%
final = t.copy()

final.to_csv("transactions.csv", index=False, sep=";")
